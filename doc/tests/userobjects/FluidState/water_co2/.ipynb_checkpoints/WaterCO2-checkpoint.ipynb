# %% [markdown]
# # Water - CO$_2$ state #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Fluid density ##
#
# Water density given by FluidState UserObject. Pressure varies from 1 MPa to 21 MPa, and temperature is 50C.

# %% [markdown]
# Read in the MOOSE data.

# %%
moose_data = pd.read_csv('gold/FluidStateWaterCO2_liquidDensity_vpp_0001.csv')

# %% [markdown]
# Read in data obtained from NIST webbook (http://webbook.nist.gov/chemistry/fluid/).

# %%
nist_data = pd.read_csv('gold/nist_water.csv', header=None, delimiter='\t')

# %%
plt.plot((1+10* moose_data.x), moose_data.FluidStateAuxVariable,'o', label='MOOSE')
plt.plot(nist_data.ix[:,1], nist_data.ix[:,2], label='NIST')
plt.legend(loc='upper left')
plt.xlabel('Pressure (MPa)')
plt.ylabel('Density (kg/m^3)')

# %% [markdown]
# ## Gas density ##
#
# CO$_2$ density given by FluidState UserObject. Pressure varies from 1 MPa to 21 MPa, and temperature is 50C.

# %% [markdown]
# Read in the MOOSE data.

# %%
moose_data = pd.read_csv('gold/FluidStateWaterCO2_gasDensity_vpp_0001.csv')

# %% [markdown]
# Read in data obtained from NIST webbook (http://webbook.nist.gov/chemistry/fluid/).

# %%
nist_data = pd.read_csv('gold/nist_co2.csv', header=None, delimiter='\t')

# %%
plt.plot((1+10* moose_data.x), moose_data.FluidStateAuxVariable,'o', label='MOOSE')
plt.plot(nist_data.ix[:,1], nist_data.ix[:,2], label='NIST')
plt.legend(loc='upper left')
plt.xlabel('Pressure (MPa)')
plt.ylabel('Density (kg/m^3)')
